# %% [markdown]
# # Seattle AirBnB data

# %% [markdown]
# ## Using data to understand the homeowner's market in Seattle
#
# I approached the data as if I were a homeowner Seattle. If I were a homeowner in Seattle, my main objective would be to offer a great experience for my guests while making a healthy profit. Hence, I structured my business understanding questions around these objectives. My questions for my analysis are thus as follows:
#
# ### Business Understanding:
# 1. Can we predict what drives higher ratings?
# 2. When are the most popular times of the year for Seattle home-owners?
# 3. When are the most profitable times of the year for Seattle home-owners?

# %% [markdown]
# ### Data Understanding
#
# #### Data Exploration
#
# All data was obtained from Kaggle: https://www.kaggle.com/airbnb/seattle/home

# %%
#import libraries and load data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython import display
import collections
import sklearn
# %matplotlib inline

listings = pd.read_csv('./seattle/listings.csv')
calendar = pd.read_csv('./seattle/calendar.csv')
reviews = pd.read_csv('./seattle/reviews.csv')

# %%
#explore columns in datasets
print(listings.columns.values)
print(calendar.columns.values)
print(reviews.columns.values)
# Out:
# ['id' 'listing_url' 'scrape_id' 'last_scraped' 'name' 'summary' 'space'
#  'description' 'experiences_offered' 'neighborhood_overview' 'notes'
#  'transit' 'thumbnail_url' 'medium_url' 'picture_url' 'xl_picture_url'
#  'host_id' 'host_url' 'host_name' 'host_since' 'host_location'
#  'host_about' 'host_response_time' 'host_response_rate'
#  'host_acceptance_rate' 'host_is_superhost' 'host_thumbnail_url'
#  'host_picture_url' 'host_neighbourhood' 'host_listings_count'
#  'host_total_listings_count' 'host_verifications' 'host_has_profile_pic'
#  'host_identity_verified' 'street' 'neighbourhood'
#  'neighbourhood_cleansed' 'neighbourhood_group_cleansed' 'city' 'state'
#  'zipcode' 'market' 'smart_location' 'country_code' 'country' 'latitude'
#  'longitude' 'is_location_exact' 'property_type' 'room_type'
#  'accommodates' 'bathrooms' 'bedrooms' 'beds' 'bed_type' 'amenities'
#  'square_feet' 'price' 'weekly_price' 'monthly_price' 'security_deposit'
#  'cleaning_fee' 'guests_included' 'extra_people' 'minimum_nights'
#  'maximum_nights' 'calendar_updated' 'has_availability' 'availability_30'
#  'availability_60' 'availability_90' 'availability_365'
#  'calendar_last_scraped' 'number_of_reviews' 'first_review' 'last_review'
#  'review_scores_rating' 'review_scores_accuracy'
#  'review_scores_cleanliness' 'review_scores_checkin'
#  'review_scores_communication' 'review_scores_location'
#  'review_scores_value' 'requires_license' 'license' 'jurisdiction_names'
#  'instant_bookable' 'cancellation_policy' 'require_guest_profile_picture'
#  'require_guest_phone_verification' 'calculated_host_listings_count'
#  'reviews_per_month']
# ['listing_id' 'date' 'available' 'price']
# ['listing_id' 'id' 'date' 'reviewer_id' 'reviewer_name' 'comments']

# %% [markdown]
# It appears that all the datasets can potentially be merged by their listing ID, if needed during analysis. First, check that all columns are variables and rows are individuals.

# %%
#check no. of rows and columns
print(listings.shape)
print(calendar.shape)
print(reviews.shape)
# Out:
# (3818, 92)
# (1393570, 4)
# (84849, 6)

# %%
#check for missing values in the columns for each dataset, get percentages
(listings.isnull().sum()/len(listings)).sort_values(ascending=False)
# Out:
# license                             1.000000
# square_feet                         0.974594
# monthly_price                       0.602672
# security_deposit                    0.511262
# weekly_price                        0.473808
# notes                               0.420639
# neighborhood_overview               0.270299
# cleaning_fee                        0.269775
# transit                             0.244631
# host_about                          0.224987
# host_acceptance_rate                0.202462
# review_scores_accuracy              0.172342
# review_scores_checkin               0.172342
# review_scores_value                 0.171818
# review_scores_location              0.171556
# review_scores_cleanliness           0.171032
# review_scores_communication         0.170508
# review_scores_rating                0.169460
# reviews_per_month                   0.164222
# first_review                        0.164222
# last_review                         0.164222
# space                               0.149031
# host_response_time                  0.136983
# host_response_rate                  0.136983
# neighbourhood                       0.108958
# xl_picture_url                      0.083814
# thumbnail_url                       0.083814
# medium_url                          0.083814
# host_neighbourhood                  0.078575
# summary                             0.046359
#                                       ...
# availability_60                     0.000000
# availability_90                     0.000000
# availability_365                    0.000000
# number_of_reviews                   0.000000
# minimum_nights                      0.000000
# requires_license                    0.000000
# jurisdiction_names                  0.000000
# instant_bookable                    0.000000
# cancellation_policy                 0.000000
# require_guest_profile_picture       0.000000
# require_guest_phone_verification    0.000000
# maximum_nights                      0.000000
# extra_people                        0.000000
# neighbourhood_group_cleansed        0.000000
# calculated_host_listings_count      0.000000
# city                                0.000000
# state                               0.000000
# market                              0.000000
# smart_location                      0.000000
# country_code                        0.000000
# country                             0.000000
# longitude                           0.000000
# guests_included                     0.000000
# is_location_exact                   0.000000
# room_type                           0.000000
# accommodates                        0.000000
# bed_type                            0.000000
# amenities                           0.000000
# price                               0.000000
# id                                  0.000000
# Length: 92, dtype: float64

# %%
#check distribution of null values
(listings.isnull().sum()/len(listings)).describe()
# Out:
# count    92.000000
# mean      0.084893
# std       0.181492
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.136983
# max       1.000000
# dtype: float64

# %% [markdown]
# For the listing dataset, it looks as though there are a number of columns containing missing values. The license column is completely null.
#
# Looking at the spread of null values, we can see that the average % of null rows in each column is around 10-11%, with 75% of columns having 17% of rows being missing. As I would prefer not to drop columns unnecessarily, I would consider drop columns with more than 30% rows that are null.

# %%
(calendar.isnull().sum()/len(calendar)).sort_values(ascending=False)
# Out:
# price         0.32939
# available     0.00000
# date          0.00000
# listing_id    0.00000
# dtype: float64

# %% [markdown]
# For the calendar dataset, the price column has 32% of rows containing null values.

# %%
(reviews.isnull().sum()/len(reviews)).sort_values(ascending=False)
# Out:
# comments         0.000212
# reviewer_name    0.000000
# reviewer_id      0.000000
# date             0.000000
# id               0.000000
# listing_id       0.000000
# dtype: float64

# %% [markdown]
# The reviews dataset has almost no missing values.
#
# In order to prepare the data for the 3 business questions, we need to look at the 3 datasets and determine which datasets and columns contained within them that are relevant to the question above.
#
# We have 3 datasets: listings, calendar and reviews. Based on our brief exploration above, we can see that the dataset most relevant to our analysis for this question is the listings dataset. The calendar dataset looks to be more relevant to supplement the listings dataset for our 2nd question on popular times and availability.
#
# Meanwhile, the reviews dataset is more relevant for qualitative predictors and is mainly unstructured data, hence we will only analyse it if we lack sufficient information to answer our questions.
#
# After determining the datasets that are relevant for answering our questions, we move to preparing the data for our analysis.

# %% [markdown]
# ### Question 1: Can we predict what drives higher ratings?
# ### Data Preparation
#
# #### Treatment of missing values
#
# Seeing as there are many missing values in the license column, and it is not relevant to the questions above, we can drop it from our analysis dataset. As mentioned above, I would also drop columns that are more than 30% of missing rows, if there are not too many and we don't foresee losing too much information.

# %%
#drop license column
listings.drop(columns=['license'],inplace=True)

# %%
#check columns >=30% missing values
[cols for cols in listings.columns.values if (listings[cols].isnull().sum()/len(listings))>=0.30]
# Out:
# ['notes', 'square_feet', 'weekly_price', 'monthly_price', 'security_deposit']

# %% [markdown]
# Considering the columns above, we know that there is the price column that would contain similar information, so we can drop the weekly_price and monthly_price columns without worrying about losing information.

# %%
#drop weekly_price, monthly_price columns
listings.drop(columns=['weekly_price','monthly_price'],inplace=True)

# %% [markdown]
# Since security deposit is an additional cost, I would rather not drop the value, but since the number of missing values are quite high, I would instead engineer the variable to become a flag for if there is a security deposit or not, as this may be more relevant to incorporate information for the missing values.

# %%
#create new variable security_deposit_flag 
listings['security_deposit_flag']=np.where(listings['security_deposit'].notnull(), 1, 0)

# %% [markdown]
# As for notes, it appears to be unstructured data. Meanwhile, for square_feet, the number of missing values are so high that I will just drop it.

# %%
#check values in notes columns
print(listings['notes'].head(10))
#drop square_feet variables
listings.drop(columns=['notes','square_feet'],inplace=True)
# Out:
# 0                                                  NaN
# 1    What's up with the free pillows?  Our home was...
# 2    Our house is located just 5 short blocks to To...
# 3                                                  NaN
# 4                                            Belltown
# 5    Let me know if you need anything or have sugge...
# 6    The room now has a mini frig to keep your favo...
# 7    There are three rentals in our back yard . If ...
# 8                                                  NaN
# 9    What's up with the free pillows?  Our home was...
# Name: notes, dtype: object

# %% [markdown]
# #### Choosing the target (y) variable
# Next, we revisit the question, which is on driving higher ratings in homes. The relevant column that can be seen as the target variable (y column) would be in the set of review_scores columns. However, we can see that there are several columns in the review_scores.

# %%
#check column names that begin with 'review_scores' 
[col for col in listings if col.startswith('review_scores_')]
# Out:
# ['review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value']

# %% [markdown]
# Based on [AirBnB's ratings methodology](https://www.airbnb.com/help/article/1257/how-do-star-ratings-work), the overall experience is the one that determines the overall experience for guests, and so the review_scores_rating column is the one I would set as my target variable.
#
# #### Feature engineering
#
# However, we need to revisit the other columns in the listings dataset. There are quite a few redundant columns that are unnecessary.
#
# For example, it is unnecessary to have columns that only contain one unique value as they don't provide any predictive power.

# %%
#find columns in dataset that only contain one unique value
one_unique=[col for col in listings.columns.values if listings[col].nunique()==1]
one_unique
# Out:
# ['scrape_id',
#  'last_scraped',
#  'experiences_offered',
#  'market',
#  'country_code',
#  'country',
#  'has_availability',
#  'calendar_last_scraped',
#  'requires_license',
#  'jurisdiction_names']

# %% [markdown]
# Any columns that contain 'url' in the name are also irrelevant as they contain no predictive power or characteristics that lead to higher ratings for homes.

# %%
#find columns containing 'url' in the name
url_col=[col for col in listings.columns.values if 'url' in col]
url_col
# Out:
# ['listing_url',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_url',
#  'host_thumbnail_url',
#  'host_picture_url']

# %%
#add url and single unique value to drop columns list
drop_cols=[]
drop_cols.extend(one_unique)
drop_cols.extend(url_col)
#drop columns from dataset
listings.drop(columns=drop_cols,inplace=True)

# %%
#get total no. of columns after dropping columns
len(listings.columns.values)
# Out:
# 70

# %% [markdown]
# For the remaining columns (ignoring the review_scores/target variable columns), we will need to look into a sample of one row from each column to determine if it would be valuable for our predictions or not, and to determine if further feature engineeringis required for some columns.
#
# In a way, we need to build our own simple data dictionary for our use, to more easily identify what kind of feature engineering is required.

# %%
#ignoring the review_scores column, look at the remaining columns, take one sample from each and build simple data dictionary
listings_sample=[(x,listings[x][1]) for x in listings.columns.values if not x.startswith('review_scores_')]
listings_sample=pd.DataFrame(listings_sample, columns=['column_name','sample_value'])
listings_sample.set_index('column_name',inplace=True)
#check types of values in each column - add new column of value_type to our data dictionary
listings_sample['value_type']=[type(x) for x in listings_sample['sample_value']]
#check how many unique values are in each column for categorical variables encoding
listings_sample['nunique']=[listings[col].nunique() for col in listings_sample.index.values]
listings_sample
# Out:
#                                                                        sample_value  \
# column_name
# id                                                                           953595
# name                                             Bright & Airy Queen Anne Apartment
# summary                           Chemically sensitive? We've removed the irrita...
# space                             Beautiful, hypoallergenic apartment in an extr...
# description                       Chemically sensitive? We've removed the irrita...
# neighborhood_overview             Queen Anne is a wonderful, truly functional vi...
# transit                           Convenient bus stops are just down the block, ...
# host_id                                                                     5177328
# host_name                                                                    Andrea
# host_since                                                               2013-02-21
# host_location                                    Seattle, Washington, United States
# host_about                        Living east coast/left coast/overseas.  Time i...
# host_response_time                                                   within an hour
# host_response_rate                                                              98%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 t
# host_neighbourhood                                                       Queen Anne
# host_listings_count                                                               6
# host_total_listings_count                                                         6
# host_verifications                ['email', 'phone', 'facebook', 'linkedin', 're...
# host_has_profile_pic                                                              t
# host_identity_verified                                                            t
# street                            7th Avenue West, Seattle, WA 98119, United States
# neighbourhood                                                            Queen Anne
# neighbourhood_cleansed                                              West Queen Anne
# neighbourhood_group_cleansed                                             Queen Anne
# city                                                                        Seattle
# state                                                                            WA
# zipcode                                                                       98119
# smart_location                                                          Seattle, WA
# ...                                                                             ...
# property_type                                                             Apartment
# room_type                                                           Entire home/apt
# accommodates                                                                      4
# bathrooms                                                                         1
# bedrooms                                                                          1
# beds                                                                              1
# bed_type                                                                   Real Bed
# amenities                         {TV,Internet,"Wireless Internet",Kitchen,"Free...
# price                                                                       $150.00
# security_deposit                                                            $100.00
# cleaning_fee                                                                 $40.00
# guests_included                                                                   1
# extra_people                                                                  $0.00
# minimum_nights                                                                    2
# maximum_nights                                                                   90
# calendar_updated                                                              today
# availability_30                                                                  13
# availability_60                                                                  13
# availability_90                                                                  16
# availability_365                                                                291
# number_of_reviews                                                                43
# first_review                                                             2013-08-19
# last_review                                                              2015-12-29
# instant_bookable                                                                  f
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     t
# require_guest_phone_verification                                                  t
# calculated_host_listings_count                                                    6
# reviews_per_month                                                              1.48
# security_deposit_flag                                                             1
#
#                                                value_type  nunique
# column_name
# id                                  <class 'numpy.int64'>     3818
# name                                        <class 'str'>     3792
# summary                                     <class 'str'>     3478
# space                                       <class 'str'>     3119
# description                                 <class 'str'>     3742
# neighborhood_overview                       <class 'str'>     2506
# transit                                     <class 'str'>     2574
# host_id                             <class 'numpy.int64'>     2751
# host_name                                   <class 'str'>     1466
# host_since                                  <class 'str'>     1380
# host_location                               <class 'str'>      120
# host_about                                  <class 'str'>     2011
# host_response_time                          <class 'str'>        4
# host_response_rate                          <class 'str'>       45
# host_acceptance_rate                        <class 'str'>        2
# host_is_superhost                           <class 'str'>        2
# host_neighbourhood                          <class 'str'>      102
# host_listings_count               <class 'numpy.float64'>       27
# host_total_listings_count         <class 'numpy.float64'>       27
# host_verifications                          <class 'str'>      116
# host_has_profile_pic                        <class 'str'>        2
# host_identity_verified                      <class 'str'>        2
# street                                      <class 'str'>     1442
# neighbourhood                               <class 'str'>       81
# neighbourhood_cleansed                      <class 'str'>       87
# neighbourhood_group_cleansed                <class 'str'>       17
# city                                        <class 'str'>        7
# state                                       <class 'str'>        2
# zipcode                                     <class 'str'>       28
# smart_location                              <class 'str'>        7
# ...                                                   ...      ...
# property_type                               <class 'str'>       16
# room_type                                   <class 'str'>        3
# accommodates                        <class 'numpy.int64'>       15
# bathrooms                         <class 'numpy.float64'>       12
# bedrooms                          <class 'numpy.float64'>        8
# beds                              <class 'numpy.float64'>       11
# bed_type                                    <class 'str'>        5
# amenities                                   <class 'str'>     3284
# price                                       <class 'str'>      273
# security_deposit                            <class 'str'>       46
# cleaning_fee                                <class 'str'>      118
# guests_included                     <class 'numpy.int64'>       15
# extra_people                                <class 'str'>       45
# minimum_nights                      <class 'numpy.int64'>       22
# maximum_nights                      <class 'numpy.int64'>       68
# calendar_updated                            <class 'str'>       34
# availability_30                     <class 'numpy.int64'>       31
# availability_60                     <class 'numpy.int64'>       61
# availability_90                     <class 'numpy.int64'>       91
# availability_365                    <class 'numpy.int64'>      363
# number_of_reviews                   <class 'numpy.int64'>      195
# first_review                                <class 'str'>      984
# last_review                                 <class 'str'>      321
# instant_bookable                            <class 'str'>        2
# cancellation_policy                         <class 'str'>        3
# require_guest_profile_picture               <class 'str'>        2
# require_guest_phone_verification            <class 'str'>        2
# calculated_host_listings_count      <class 'numpy.int64'>       18
# reviews_per_month                 <class 'numpy.float64'>      654
# security_deposit_flag               <class 'numpy.int64'>        2
#
# [63 rows x 3 columns]

# %% [markdown]
# From our data dictionary above, we can see that there are quite a number of columns with unstructured data in the form of text and sentences, e.g. name, summary, description, neighbourhood_overview, etc. We will decide what to do with them later as there will be quite a lot of engineering to be done on those features.
#
# For the other columns, we can see some that may not be relevant in the predicitive model. For example, the host particulars like host_id, host_name, host_since, host_location, host_about, host_verifications don't look like they will be useful, as they contain mainly unstructured and irrelevant information to our question of interest.

# %%
#remove relevant columns, update data dictionary at the same time
drop_cols=['host_id', 'host_name', 'host_since', 'host_location', 'host_about', 'host_verifications']
listings.drop(columns=drop_cols,inplace=True)
listings_sample.drop(drop_cols,inplace=True)

# %% [markdown]
# Furthermore, there are some redundant columns that can be removed as well, for example the neighbourhood data (it looks like they have been aggregated into neighbourhood_group_cleansed which may be more useful).

# %%
#check neighbourhood columns to see which one would provide more information
print(listings['neighbourhood_cleansed'].unique())
print(listings['neighbourhood_group_cleansed'].unique())
print(listings['neighbourhood'].unique())
# Out:
# ['West Queen Anne' 'Adams' 'West Woodland' 'East Queen Anne' 'Wallingford'
#  'North Queen Anne' 'Green Lake' 'Westlake' 'Mann' 'Madrona'
#  'University District' 'Harrison/Denny-Blaine' 'Minor' 'Leschi' 'Atlantic'
#  'Pike-Market' 'Eastlake' 'South Lake Union' 'Lawton Park' 'Briarcliff'
#  'Belltown' 'International District' 'Central Business District'
#  'First Hill' 'Yesler Terrace' 'Pioneer Square' 'Gatewood' 'Arbor Heights'
#  'Alki' 'North Admiral' 'Crown Hill' 'Fairmount Park' 'Genesee' 'Interbay'
#  'Industrial District' 'Mid-Beacon Hill' 'South Beacon Hill' 'Greenwood'
#  'Holly Park' 'Fauntleroy' 'North Beacon Hill' 'Mount Baker' 'Brighton'
#  'South Delridge' 'View Ridge' 'Dunlap' 'Rainier Beach' 'Columbia City'
#  'Seward Park' 'North Delridge' 'Maple Leaf' 'Ravenna' 'Riverview'
#  'Portage Bay' 'Bryant' 'Montlake' 'Broadway' 'Loyal Heights'
#  'Victory Heights' 'Matthews Beach' 'Whittier Heights' 'Meadowbrook'
#  'Olympic Hills' 'Roosevelt' 'Lower Queen Anne' 'Wedgwood'
#  'North Beach/Blue Ridge' 'Cedar Park' 'Bitter Lake' 'Sunset Hill'
#  'Haller Lake' 'Pinehurst' 'North College Park' 'Phinney Ridge'
#  'Windermere' 'Laurelhurst' 'Southeast Magnolia' 'High Point' 'Seaview'
#  'Georgetown' 'South Park' 'Roxhill' 'Highland Park' 'Madison Park'
#  'Stevens' 'Broadview' 'Fremont']
# ['Queen Anne' 'Ballard' 'Other neighborhoods' 'Cascade' 'Central Area'
#  'University District' 'Downtown' 'Magnolia' 'West Seattle' 'Interbay'
#  'Beacon Hill' 'Rainier Valley' 'Delridge' 'Seward Park' 'Northgate'
#  'Capitol Hill' 'Lake City']
# ['Queen Anne' nan 'Ballard' 'Phinney Ridge' 'Fremont' 'Lower Queen Anne'
#  'Westlake' 'Wallingford' 'Green Lake' 'Minor' 'Madrona'
#  'Harrison/Denny-Blaine' 'Leschi' 'University District' 'Roosevelt'
#  'Madison Park' 'Capitol Hill' 'Atlantic' 'North Beacon Hill'
#  'Central Business District' 'Pike Place Market' 'Pike Market' 'Eastlake'
#  'Portage Bay' 'South Lake Union' 'Magnolia' 'Belltown'
#  'International District' 'Yesler Terrace' 'First Hill' 'Pioneer Square'
#  'Gatewood' 'The Junction' 'Arbor Heights' 'Alki' 'North Admiral'
#  'Crown Hill' 'Genesee' 'Fairmount Park' 'Interbay' 'Industrial District'
#  'Holly Park' 'South Beacon Hill' 'Greenwood' 'Bitter Lake' 'Fauntleroy'
#  'Mount Baker' 'Columbia City' 'Seward Park' 'Brighton' 'South Delridge'
#  'Highland Park' 'High Point' 'View Ridge' 'Windermere' 'Dunlap'
#  'Rainier Beach' 'North Delridge' 'Maple Leaf' 'Bryant' 'Ravenna'
#  'Wedgewood' 'Riverview' 'Montlake' 'Broadway' 'Stevens' 'Victory Heights'
#  'Mathews Beach' 'Cedar Park' 'Meadowbrook' 'Olympic Hills'
#  'North Beach/Blue Ridge' 'Broadview' 'Haller Lake' 'Pinehurst'
#  'Licton Springs' 'North College Park' 'Laurelhurst' 'Seaview'
#  'Georgetown' 'South Park' 'Roxhill']

# %% [markdown]
# After checking the neighbourhood columns above, I decided to use neighbourhood_group_cleansed instead of the other two variables as it provides less number of levels as a categorical variable, while also offering a good amount of information.

# %%
#remove redundant columns, update data dictionary at the same time
drop_cols=['neighbourhood','host_neighbourhood','neighbourhood_cleansed']
listings.drop(columns=drop_cols,inplace=True)
listings_sample.drop(drop_cols,inplace=True)

# %% [markdown]
# City, State, Street, smart_location, latitude and longitude are all redundant data as all listings are in Seattle, WA. We have information on location through other variables like neighbourhood and zip code. Thus they can be dropped. The variables first_review and last_review are dates that I am not going to focus on in my analysis for question 1. This also applied to the variable calendar_updated.

# %%
#remove redundant data, update data dictionary at the same time
drop_cols=['city','state','street','smart_location',
            'latitude','longitude','first_review','last_review','calendar_updated']
listings.drop(columns=drop_cols,inplace=True)
listings_sample.drop(drop_cols,inplace=True)

# %% [markdown]
# After removing the 'low-hanging fruit' of irrelevant columns, we need to revisit our data dictionary and check if the values in each column can be processed by the model.
# number of levels they have that are required to be encoded.

# %%
print('No. of columns= {} columns.'.format(len(listings_sample)))
listings_sample
# Out:
# No. of columns= 45 columns.
#                                                                        sample_value  \
# column_name
# id                                                                           953595
# name                                             Bright & Airy Queen Anne Apartment
# summary                           Chemically sensitive? We've removed the irrita...
# space                             Beautiful, hypoallergenic apartment in an extr...
# description                       Chemically sensitive? We've removed the irrita...
# neighborhood_overview             Queen Anne is a wonderful, truly functional vi...
# transit                           Convenient bus stops are just down the block, ...
# host_response_time                                                   within an hour
# host_response_rate                                                              98%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 t
# host_listings_count                                                               6
# host_total_listings_count                                                         6
# host_has_profile_pic                                                              t
# host_identity_verified                                                            t
# neighbourhood_group_cleansed                                             Queen Anne
# zipcode                                                                       98119
# is_location_exact                                                                 t
# property_type                                                             Apartment
# room_type                                                           Entire home/apt
# accommodates                                                                      4
# bathrooms                                                                         1
# bedrooms                                                                          1
# beds                                                                              1
# bed_type                                                                   Real Bed
# amenities                         {TV,Internet,"Wireless Internet",Kitchen,"Free...
# price                                                                       $150.00
# security_deposit                                                            $100.00
# cleaning_fee                                                                 $40.00
# guests_included                                                                   1
# extra_people                                                                  $0.00
# minimum_nights                                                                    2
# maximum_nights                                                                   90
# availability_30                                                                  13
# availability_60                                                                  13
# availability_90                                                                  16
# availability_365                                                                291
# number_of_reviews                                                                43
# instant_bookable                                                                  f
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     t
# require_guest_phone_verification                                                  t
# calculated_host_listings_count                                                    6
# reviews_per_month                                                              1.48
# security_deposit_flag                                                             1
#
#                                                value_type  nunique
# column_name
# id                                  <class 'numpy.int64'>     3818
# name                                        <class 'str'>     3792
# summary                                     <class 'str'>     3478
# space                                       <class 'str'>     3119
# description                                 <class 'str'>     3742
# neighborhood_overview                       <class 'str'>     2506
# transit                                     <class 'str'>     2574
# host_response_time                          <class 'str'>        4
# host_response_rate                          <class 'str'>       45
# host_acceptance_rate                        <class 'str'>        2
# host_is_superhost                           <class 'str'>        2
# host_listings_count               <class 'numpy.float64'>       27
# host_total_listings_count         <class 'numpy.float64'>       27
# host_has_profile_pic                        <class 'str'>        2
# host_identity_verified                      <class 'str'>        2
# neighbourhood_group_cleansed                <class 'str'>       17
# zipcode                                     <class 'str'>       28
# is_location_exact                           <class 'str'>        2
# property_type                               <class 'str'>       16
# room_type                                   <class 'str'>        3
# accommodates                        <class 'numpy.int64'>       15
# bathrooms                         <class 'numpy.float64'>       12
# bedrooms                          <class 'numpy.float64'>        8
# beds                              <class 'numpy.float64'>       11
# bed_type                                    <class 'str'>        5
# amenities                                   <class 'str'>     3284
# price                                       <class 'str'>      273
# security_deposit                            <class 'str'>       46
# cleaning_fee                                <class 'str'>      118
# guests_included                     <class 'numpy.int64'>       15
# extra_people                                <class 'str'>       45
# minimum_nights                      <class 'numpy.int64'>       22
# maximum_nights                      <class 'numpy.int64'>       68
# availability_30                     <class 'numpy.int64'>       31
# availability_60                     <class 'numpy.int64'>       61
# availability_90                     <class 'numpy.int64'>       91
# availability_365                    <class 'numpy.int64'>      363
# number_of_reviews                   <class 'numpy.int64'>      195
# instant_bookable                            <class 'str'>        2
# cancellation_policy                         <class 'str'>        3
# require_guest_profile_picture               <class 'str'>        2
# require_guest_phone_verification            <class 'str'>        2
# calculated_host_listings_count      <class 'numpy.int64'>       18
# reviews_per_month                 <class 'numpy.float64'>      654
# security_deposit_flag               <class 'numpy.int64'>        2

# %% [markdown]
# From our simple data dictionary, we can see that a lot of feature engineering is required for many of the columns. For example, the host_response_rate and host_acceptance_rate are recorded as type strings eventhough they are percentages. The pricing data (e.g. price, weekly_price, etc.) are also recorded as strings, eventhough they would be more useful to the predictive model as numerical values.
#
# Additionally, the columns 'amenities' are also recorded as lists of strings, so we will need to process those as well.

# %% [markdown]
# #### Encoding for categorical variables
#
# Leaving all columns containing unstructured data for later, we first encode all categorical variables. Referring to our data dictionary, the categorical variables are as follows:
#
#     host_response_time
#     host_is_superhost
#     host_has_profile_pic
#     host_identity_verified
#     neighbourhood_group_cleansed
#     zipcode
#     is_location_exact
#     property_type
#     room_type
#     bed_type
#     amenities (which needs further processing)
#     instant_bookable
#     cancellation_policy
#     require_guest_profile_picture
#     require_guest_phone_verification
#     security_deposit_flag
#
# I created the security_deposit_flag variable so we can leave that aside. But for the others, we need to encode them according to their levels. With that, I used pandas_getdummies function.

# %%
#check zipcode unique values - appears to have a weird value there
print(listings['zipcode'].unique())
#convert weird value into 98122
listings.loc[listings['zipcode'] == '99\n98122', 'zipcode'] = '98122'
print(listings['zipcode'].unique())
# Out:
# ['98119' '98109' '98107' '98117' nan '98103' '98105' '98115' '98101'
#  '98122' '98112' '98144' '99\n98122' '98121' '98102' '98199' '98104'
#  '98134' '98136' '98126' '98146' '98116' '98177' '98118' '98108' '98133'
#  '98106' '98178' '98125']
# ['98119' '98109' '98107' '98117' nan '98103' '98105' '98115' '98101'
#  '98122' '98112' '98144' '98121' '98102' '98199' '98104' '98134' '98136'
#  '98126' '98146' '98116' '98177' '98118' '98108' '98133' '98106' '98178'
#  '98125']

# %%
#encode categorical variables
binary_cols=['host_is_superhost','host_has_profile_pic','host_identity_verified','is_location_exact'
             ,'instant_bookable','require_guest_profile_picture','require_guest_phone_verification']
listings[binary_cols]=np.where(listings[binary_cols]=='t', 1, 0)
encode_cols=['host_response_time','neighbourhood_group_cleansed','zipcode'
             ,'property_type','room_type','bed_type','cancellation_policy']
listings=pd.get_dummies(data=listings, columns=encode_cols,drop_first=True)

# %% [markdown]
# Next we need to look at the 'amenities' column and engineer it to extract categorical variables.

# %% [markdown]
# #### Transforming strings into numerical values
#
# Now we look at the numerical values

# %% [markdown]
# Now we need to revisit what to do with the columns containing unstructured data.
#
# After reading around, I decided that a simple natural language processing model can be used to transform the unstructured text into feature vectors that could be processed by a machine learning model. In a way, I had to do basic feature extraction on those columns to extract the textual features in numerical format.
# I referred to this article [here](https://www.analyticsvidhya.com/blog/2018/02/the-different-methods-deal-text-data-predictive-python/) for extensive guidance on how to do this.

# %%
listings_test=listings.copy()

# %%
# #split amenities by commas
# listings_test['amenities']=listings_test['amenities'].str.split(',')
# #get unique list of amenities
# for x in range(len(listings_test['amenities'])):
#     amenities_list=[listings_test['amenities'][x][y].strip('{}""') for y in range(len(listings_test['amenities'][x]))]

# %%
#get dataframe of listings with amenities split up
amenities_df=listings_test['amenities'].str.split(',',expand=True)
amenities_df
# Out:
#                             0                             1   \
# 0                          {TV                    "Cable TV"
# 1                          {TV                      Internet
# 2                          {TV                    "Cable TV"
# 3                    {Internet           "Wireless Internet"
# 4                          {TV                    "Cable TV"
# 5         {"Wireless Internet"    "Free Parking on Premises"
# 6         {"Wireless Internet"    "Free Parking on Premises"
# 7         {"Wireless Internet"  "Pets live on this property"
# 8                          {TV                    "Cable TV"
# 9                          {TV                      Internet
# 10                         {TV                    "Cable TV"
# 11                         {TV                    "Cable TV"
# 12                         {TV                    "Cable TV"
# 13                         {TV                    "Cable TV"
# 14                         {TV                    "Cable TV"
# 15                         {TV                    "Cable TV"
# 16                   {Internet           "Wireless Internet"
# 17        {"Wireless Internet"    "Free Parking on Premises"
# 18                         {TV                    "Cable TV"
# 19                         {TV                    "Cable TV"
# 20                   {Internet           "Wireless Internet"
# 21                 {"Cable TV"                      Internet
# 22                         {TV           "Wireless Internet"
# 23                   {Internet           "Wireless Internet"
# 24                         {TV                    "Cable TV"
# 25                         {TV                    "Cable TV"
# 26                 {"Cable TV"           "Wireless Internet"
# 27        {"Wireless Internet"  "Pets live on this property"
# 28                         {TV                    "Cable TV"
# 29                         {TV                    "Cable TV"
# ...                        ...                           ...
# 3788                       {TV                      Internet
# 3789                       {TV                      Internet
# 3790                       {TV                      Internet
# 3791                       {TV                    "Cable TV"
# 3792                       {TV                    "Cable TV"
# 3793                       {TV                    "Cable TV"
# 3794      {"Wireless Internet"                       Kitchen
# 3795                       {TV                    "Cable TV"
# 3796                       {TV                    "Cable TV"
# 3797      {"Wireless Internet"                       Kitchen
# 3798                       {TV                      Internet
# 3799                       {TV                      Internet
# 3800                       {TV                    "Cable TV"
# 3801                       {TV                    "Cable TV"
# 3802                       {TV           "Wireless Internet"
# 3803                       {TV                      Internet
# 3804                       {TV                      Internet
# 3805                       {TV                      Internet
# 3806                 {Internet           "Wireless Internet"
# 3807                       {TV                    "Cable TV"
# 3808                       {TV                    "Cable TV"
# 3809  {"Wheelchair Accessible"                       Kitchen
# 3810                       {TV                    "Cable TV"
# 3811                       {TV                    "Cable TV"
# 3812                 {Internet           "Wireless Internet"
# 3813                       {TV                    "Cable TV"
# 3814                       {TV                    "Cable TV"
# 3815               {"Cable TV"           "Wireless Internet"
# 3816                       {TV           "Wireless Internet"
# 3817                       {TV                    "Cable TV"
#
#                        2                           3   \
# 0                Internet         "Wireless Internet"
# 1     "Wireless Internet"                     Kitchen
# 2                Internet         "Wireless Internet"
# 3                 Kitchen          "Indoor Fireplace"
# 4                Internet         "Wireless Internet"
# 5                 Heating            "Smoke Detector"
# 6                 Heating            "Smoke Detector"
# 7                  Dog(s)                     Heating
# 8                Internet         "Wireless Internet"
# 9     "Wireless Internet"                     Kitchen
# 10               Internet         "Wireless Internet"
# 11    "Wireless Internet"                     Kitchen
# 12               Internet         "Wireless Internet"
# 13               Internet         "Wireless Internet"
# 14               Internet         "Wireless Internet"
# 15               Internet                     Kitchen
# 16         "Pets Allowed"                   Breakfast
# 17                Heating            "Smoke Detector"
# 18               Internet         "Wireless Internet"
# 19    "Wireless Internet"                     Kitchen
# 20                Kitchen  "Free Parking on Premises"
# 21    "Wireless Internet"  "Free Parking on Premises"
# 22                Kitchen  "Free Parking on Premises"
# 23     "Air Conditioning"  "Free Parking on Premises"
# 24    "Wireless Internet"                     Kitchen
# 25    "Wireless Internet"          "Air Conditioning"
# 26                Kitchen  "Free Parking on Premises"
# 27                 Dog(s)                     Heating
# 28    "Wireless Internet"                     Kitchen
# 29    "Wireless Internet"     "Wheelchair Accessible"
# ...                   ...                         ...
# 3788  "Wireless Internet"                     Kitchen
# 3789  "Wireless Internet"                     Kitchen
# 3790  "Wireless Internet"                     Kitchen
# 3791             Internet         "Wireless Internet"
# 3792             Internet         "Wireless Internet"
# 3793             Internet         "Wireless Internet"
# 3794              Heating            "Smoke Detector"
# 3795             Internet         "Wireless Internet"
# 3796  "Wireless Internet"                     Kitchen
# 3797              Heating                      Washer
# 3798  "Wireless Internet"                     Kitchen
# 3799  "Wireless Internet"                     Kitchen
# 3800             Internet         "Wireless Internet"
# 3801             Internet         "Wireless Internet"
# 3802              Kitchen              "Pets Allowed"
# 3803  "Wireless Internet"                     Kitchen
# 3804  "Wireless Internet"                     Kitchen
# 3805  "Wireless Internet"          "Air Conditioning"
# 3806              Kitchen                     Heating
# 3807             Internet         "Wireless Internet"
# 3808             Internet         "Wireless Internet"
# 3809              Heating       "Family/Kid Friendly"
# 3810             Internet         "Wireless Internet"
# 3811             Internet         "Wireless Internet"
# 3812              Kitchen  "Free Parking on Premises"
# 3813             Internet         "Wireless Internet"
# 3814             Internet         "Wireless Internet"
# 3815              Kitchen  "Free Parking on Premises"
# 3816              Kitchen  "Free Parking on Premises"
# 3817             Internet         "Wireless Internet"
#
#                                 4                             5   \
# 0               "Air Conditioning"                       Kitchen
# 1       "Free Parking on Premises"    "Buzzer/Wireless Intercom"
# 2               "Air Conditioning"                       Kitchen
# 3                          Heating         "Family/Kid Friendly"
# 4                          Kitchen                       Heating
# 5                       Essentials                      Shampoo}
# 6                  "First Aid Kit"                    Essentials
# 7            "Family/Kid Friendly"                    Essentials
# 8                          Kitchen                     Breakfast
# 9       "Free Parking on Premises"    "Buzzer/Wireless Intercom"
# 10                         Kitchen    "Free Parking on Premises"
# 11      "Free Parking on Premises"            "Indoor Fireplace"
# 12                         Kitchen    "Free Parking on Premises"
# 13                         Kitchen                       Heating
# 14                         Kitchen    "Free Parking on Premises"
# 15      "Free Parking on Premises"                       Heating
# 16    "Pets live on this property"                        Cat(s)
# 17      "Carbon Monoxide Detector"           "Fire Extinguisher"
# 18                         Kitchen    "Free Parking on Premises"
# 19      "Free Parking on Premises"                "Pets Allowed"
# 20                  "Pets Allowed"        "Elevator in Building"
# 21    "Pets live on this property"                       Heating
# 22              "Indoor Fireplace"                       Heating
# 23                  "Pets Allowed"                       Heating
# 24      "Free Parking on Premises"            "Indoor Fireplace"
# 25         "Wheelchair Accessible"                       Kitchen
# 26                         Heating         "Family/Kid Friendly"
# 27           "Family/Kid Friendly"                   Essentials}
# 28      "Free Parking on Premises"            "Indoor Fireplace"
# 29                         Kitchen            "Indoor Fireplace"
# ...                            ...                           ...
# 3788                       Heating         "Family/Kid Friendly"
# 3789                       Heating              "Smoke Detector"
# 3790  "Pets live on this property"                        Dog(s)
# 3791    "Free Parking on Premises"                       Heating
# 3792            "Air Conditioning"                       Kitchen
# 3793            "Air Conditioning"                       Kitchen
# 3794    "Carbon Monoxide Detector"                    Essentials
# 3795                       Kitchen                "Pets Allowed"
# 3796    "Free Parking on Premises"  "Pets live on this property"
# 3797                         Dryer              "Smoke Detector"
# 3798    "Free Parking on Premises"                           Gym
# 3799    "Free Parking on Premises"                           Gym
# 3800            "Air Conditioning"                       Kitchen
# 3801                       Kitchen    "Free Parking on Premises"
# 3802                       Heating                        Washer
# 3803    "Free Parking on Premises"                "Pets Allowed"
# 3804                       Heating              "Smoke Detector"
# 3805       "Wheelchair Accessible"                       Kitchen
# 3806              "Smoke Detector"    "Carbon Monoxide Detector"
# 3807                       Kitchen        "Elevator in Building"
# 3808            "Air Conditioning"                       Kitchen
# 3809              "Smoke Detector"    "Carbon Monoxide Detector"
# 3810                       Kitchen  "Pets live on this property"
# 3811            "Air Conditioning"                       Kitchen
# 3812            "Indoor Fireplace"                       Heating
# 3813            "Air Conditioning"       "Wheelchair Accessible"
# 3814                       Kitchen    "Free Parking on Premises"
# 3815                     Breakfast  "Pets live on this property"
# 3816        "Elevator in Building"                       Heating
# 3817                       Kitchen    "Free Parking on Premises"
#
#                                 6                           7   \
# 0                          Heating       "Family/Kid Friendly"
# 1                          Heating       "Family/Kid Friendly"
# 2       "Free Parking on Premises"              "Pets Allowed"
# 3                           Washer                       Dryer
# 4            "Family/Kid Friendly"            "Smoke Detector"
# 5                             None                        None
# 6                         Shampoo}                        None
# 7                         Shampoo}                        None
# 8               "Indoor Fireplace"                     Heating
# 9                          Heating       "Family/Kid Friendly"
# 10                         Heating                      Washer
# 11                         Heating            "Smoke Detector"
# 12      "Buzzer/Wireless Intercom"                     Heating
# 13           "Family/Kid Friendly"                      Washer
# 14              "Indoor Fireplace"                     Heating
# 15           "Family/Kid Friendly"                      Washer
# 16                         Heating                      Washer
# 17                      Essentials                    Shampoo}
# 18    "Pets live on this property"                      Dog(s)
# 19    "Pets live on this property"                      Dog(s)
# 20                         Heating            "Smoke Detector"
# 21           "Family/Kid Friendly"                       Dryer
# 22           "Family/Kid Friendly"                      Washer
# 23           "Family/Kid Friendly"                      Washer
# 24                         Heating                      Washer
# 25      "Free Parking on Premises"          "Indoor Fireplace"
# 26                          Washer                       Dryer
# 27                            None                        None
# 28                         Heating       "Family/Kid Friendly"
# 29      "Buzzer/Wireless Intercom"                     Heating
# ...                            ...                         ...
# 3788                        Washer                       Dryer
# 3789    "Carbon Monoxide Detector"             "First Aid Kit"
# 3790            "Indoor Fireplace"                     Heating
# 3791              "Smoke Detector"  "Carbon Monoxide Detector"
# 3792                       Heating       "Family/Kid Friendly"
# 3793    "Free Parking on Premises"                     Heating
# 3794                      Shampoo}                        None
# 3795                       Heating       "Family/Kid Friendly"
# 3796                        Dog(s)                      Cat(s)
# 3797    "Carbon Monoxide Detector"         "Fire Extinguisher"
# 3798  "Pets live on this property"                      Dog(s)
# 3799            "Indoor Fireplace"                     Heating
# 3800    "Free Parking on Premises"                   Breakfast
# 3801                       Heating       "Family/Kid Friendly"
# 3802                         Dryer            "Smoke Detector"
# 3803            "Indoor Fireplace"                     Heating
# 3804    "Carbon Monoxide Detector"             "First Aid Kit"
# 3805    "Free Parking on Premises"                     Heating
# 3806               "First Aid Kit"               "Safety Card"
# 3807                       Heating                      Washer
# 3808    "Free Parking on Premises"                     Heating
# 3809           "Fire Extinguisher"                  Essentials
# 3810                        Cat(s)                     Heating
# 3811            "Indoor Fireplace"                     Heating
# 3812         "Family/Kid Friendly"                      Washer
# 3813                       Kitchen  "Free Parking on Premises"
# 3814                       Heating       "Family/Kid Friendly"
# 3815                        Dog(s)                      Cat(s)
# 3816              "Smoke Detector"                  Essentials
# 3817  "Pets live on this property"                      Dog(s)
#
#                                 8                           9   ...   \
# 0                           Washer                      Dryer}  ...
# 1                           Washer                       Dryer  ...
# 2     "Pets live on this property"                      Dog(s)  ...
# 3                 "Smoke Detector"  "Carbon Monoxide Detector"  ...
# 4       "Carbon Monoxide Detector"             "First Aid Kit"  ...
# 5                             None                        None  ...
# 6                             None                        None  ...
# 7                             None                        None  ...
# 8                           Washer                       Dryer  ...
# 9                           Washer                       Dryer  ...
# 10                           Dryer            "Smoke Detector"  ...
# 11      "Carbon Monoxide Detector"         "Fire Extinguisher"  ...
# 12           "Family/Kid Friendly"                      Washer  ...
# 13                           Dryer            "Smoke Detector"  ...
# 14           "Family/Kid Friendly"       "Suitable for Events"  ...
# 15                           Dryer            "Smoke Detector"  ...
# 16                           Dryer            "Smoke Detector"  ...
# 17                            None                        None  ...
# 18              "Indoor Fireplace"  "Buzzer/Wireless Intercom"  ...
# 19                          Cat(s)          "Indoor Fireplace"  ...
# 20      "Carbon Monoxide Detector"                  Essentials  ...
# 21                "Smoke Detector"             "First Aid Kit"  ...
# 22                           Dryer            "Smoke Detector"  ...
# 23                           Dryer            "Smoke Detector"  ...
# 24                           Dryer            "Smoke Detector"  ...
# 25                         Heating       "Family/Kid Friendly"  ...
# 26                "Smoke Detector"             "First Aid Kit"  ...
# 27                            None                        None  ...
# 28                          Washer                       Dryer  ...
# 29           "Family/Kid Friendly"                      Washer  ...
# ...                            ...                         ...  ...
# 3788              "Smoke Detector"  "Carbon Monoxide Detector"  ...
# 3789           "Fire Extinguisher"                  Essentials  ...
# 3790         "Family/Kid Friendly"                      Washer  ...
# 3791                   Essentials}                        None  ...
# 3792                        Washer                       Dryer  ...
# 3793                        Washer                       Dryer  ...
# 3794                          None                        None  ...
# 3795         "Suitable for Events"            "Smoke Detector"  ...
# 3796                "Other pet(s)"                     Heating  ...
# 3797                    Essentials                     Shampoo  ...
# 3798            "Indoor Fireplace"                     Heating  ...
# 3799         "Family/Kid Friendly"                      Washer  ...
# 3800                     "Hot Tub"                     Heating  ...
# 3801                        Washer                       Dryer  ...
# 3802    "Carbon Monoxide Detector"             "First Aid Kit"  ...
# 3803         "Family/Kid Friendly"                       Dryer  ...
# 3804           "Fire Extinguisher"                  Essentials  ...
# 3805         "Family/Kid Friendly"                      Washer  ...
# 3806           "Fire Extinguisher"                 Essentials}  ...
# 3807                         Dryer            "Smoke Detector"  ...
# 3808         "Family/Kid Friendly"                      Washer  ...
# 3809                      Shampoo}                        None  ...
# 3810         "Family/Kid Friendly"                      Washer  ...
# 3811                        Washer                       Dryer  ...
# 3812                         Dryer            "Smoke Detector"  ...
# 3813                       Heating       "Family/Kid Friendly"  ...
# 3814              "Smoke Detector"         "Fire Extinguisher"  ...
# 3815                       Heating                      Washer  ...
# 3816                       Hangers                "Hair Dryer"  ...
# 3817        "Elevator in Building"                   "Hot Tub"  ...
#
#                                 20                            21    22    23  \
# 0                             None                          None  None  None
# 1                             None                          None  None  None
# 2                         Shampoo}                          None  None  None
# 3                             None                          None  None  None
# 4                             None                          None  None  None
# 5                             None                          None  None  None
# 6                             None                          None  None  None
# 7                             None                          None  None  None
# 8                             None                          None  None  None
# 9                             None                          None  None  None
# 10    "Laptop Friendly Workspace"}                          None  None  None
# 11                            None                          None  None  None
# 12                            None                          None  None  None
# 13                            None                          None  None  None
# 14                            None                          None  None  None
# 15                            None                          None  None  None
# 16                            None                          None  None  None
# 17                            None                          None  None  None
# 18                            None                          None  None  None
# 19                            None                          None  None  None
# 20                            None                          None  None  None
# 21                            None                          None  None  None
# 22                            None                          None  None  None
# 23                            None                          None  None  None
# 24                            None                          None  None  None
# 25                            None                          None  None  None
# 26                            None                          None  None  None
# 27                            None                          None  None  None
# 28                            None                          None  None  None
# 29                            None                          None  None  None
# ...                            ...                           ...   ...   ...
# 3788                          None                          None  None  None
# 3789                          None                          None  None  None
# 3790                          None                          None  None  None
# 3791                          None                          None  None  None
# 3792                          None                          None  None  None
# 3793                          None                          None  None  None
# 3794                          None                          None  None  None
# 3795                          None                          None  None  None
# 3796                          None                          None  None  None
# 3797                          None                          None  None  None
# 3798                          None                          None  None  None
# 3799                          None                          None  None  None
# 3800                          None                          None  None  None
# 3801                          None                          None  None  None
# 3802                          None                          None  None  None
# 3803  "Laptop Friendly Workspace"}                          None  None  None
# 3804                          None                          None  None  None
# 3805                          None                          None  None  None
# 3806                          None                          None  None  None
# 3807                          None                          None  None  None
# 3808                          None                          None  None  None
# 3809                          None                          None  None  None
# 3810                  "Hair Dryer"                         Iron}  None  None
# 3811                          None                          None  None  None
# 3812                          None                          None  None  None
# 3813                          None                          None  None  None
# 3814                          None                          None  None  None
# 3815                          None                          None  None  None
# 3816                          None                          None  None  None
# 3817                          Iron  "Laptop Friendly Workspace"}  None  None
#
#         24    25    26    27    28    29
# 0     None  None  None  None  None  None
# 1     None  None  None  None  None  None
# 2     None  None  None  None  None  None
# 3     None  None  None  None  None  None
# 4     None  None  None  None  None  None
# 5     None  None  None  None  None  None
# 6     None  None  None  None  None  None
# 7     None  None  None  None  None  None
# 8     None  None  None  None  None  None
# 9     None  None  None  None  None  None
# 10    None  None  None  None  None  None
# 11    None  None  None  None  None  None
# 12    None  None  None  None  None  None
# 13    None  None  None  None  None  None
# 14    None  None  None  None  None  None
# 15    None  None  None  None  None  None
# 16    None  None  None  None  None  None
# 17    None  None  None  None  None  None
# 18    None  None  None  None  None  None
# 19    None  None  None  None  None  None
# 20    None  None  None  None  None  None
# 21    None  None  None  None  None  None
# 22    None  None  None  None  None  None
# 23    None  None  None  None  None  None
# 24    None  None  None  None  None  None
# 25    None  None  None  None  None  None
# 26    None  None  None  None  None  None
# 27    None  None  None  None  None  None
# 28    None  None  None  None  None  None
# 29    None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...
# 3788  None  None  None  None  None  None
# 3789  None  None  None  None  None  None
# 3790  None  None  None  None  None  None
# 3791  None  None  None  None  None  None
# 3792  None  None  None  None  None  None
# 3793  None  None  None  None  None  None
# 3794  None  None  None  None  None  None
# 3795  None  None  None  None  None  None
# 3796  None  None  None  None  None  None
# 3797  None  None  None  None  None  None
# 3798  None  None  None  None  None  None
# 3799  None  None  None  None  None  None
# 3800  None  None  None  None  None  None
# 3801  None  None  None  None  None  None
# 3802  None  None  None  None  None  None
# 3803  None  None  None  None  None  None
# 3804  None  None  None  None  None  None
# 3805  None  None  None  None  None  None
# 3806  None  None  None  None  None  None
# 3807  None  None  None  None  None  None
# 3808  None  None  None  None  None  None
# 3809  None  None  None  None  None  None
# 3810  None  None  None  None  None  None
# 3811  None  None  None  None  None  None
# 3812  None  None  None  None  None  None
# 3813  None  None  None  None  None  None
# 3814  None  None  None  None  None  None
# 3815  None  None  None  None  None  None
# 3816  None  None  None  None  None  None
# 3817  None  None  None  None  None  None
#
# [3818 rows x 30 columns]

# %%
#remove punctuation from amenities dataframe
amenities_df=pd.DataFrame(np.array([amenities_df[x].str.replace('[^\w\s]','') for x in amenities_df.columns.values])).transpose()

# %%
#get listings with most amenities
amenities_df[amenities_df.transpose().isnull().sum()==0]
# Out:
#       0         1                  2                  3   \
# 1330  TV  Cable TV           Internet  Wireless Internet
# 1421  TV  Internet  Wireless Internet   Air Conditioning
# 2746  TV  Cable TV           Internet  Wireless Internet
# 2951  TV  Cable TV           Internet  Wireless Internet
#
#                          4                      5                         6   \
# 1330  Wheelchair Accessible                Kitchen  Free Parking on Premises
# 1421  Wheelchair Accessible                   Pool                   Kitchen
# 2746       Air Conditioning  Wheelchair Accessible                   Kitchen
# 2951       Air Conditioning  Wheelchair Accessible                   Kitchen
#
#                             7             8          9   \
# 1330              Pets Allowed       Doorman        Gym
# 1421  Free Parking on Premises  Pets Allowed        Gym
# 2746  Free Parking on Premises           Gym  Breakfast
# 2951  Free Parking on Premises  Pets Allowed  Breakfast
#
#                 ...                         20           21  \
# 1330            ...              First Aid Kit  Safety Card
# 1421            ...              First Aid Kit  Safety Card
# 2746            ...              First Aid Kit  Safety Card
# 2951            ...              First Aid Kit  Safety Card
#
#                      22          23       24              25       26  \
# 1330  Fire Extinguisher  Essentials  Shampoo  24Hour Checkin  Hangers
# 1421  Fire Extinguisher  Essentials  Shampoo  24Hour Checkin  Hangers
# 2746  Fire Extinguisher  Essentials  Shampoo  24Hour Checkin  Hangers
# 2951  Fire Extinguisher  Essentials  Shampoo  24Hour Checkin  Hangers
#
#               27    28                         29
# 1330  Hair Dryer  Iron  Laptop Friendly Workspace
# 1421  Hair Dryer  Iron  Laptop Friendly Workspace
# 2746  Hair Dryer  Iron  Laptop Friendly Workspace
# 2951  Hair Dryer  Iron  Laptop Friendly Workspace
#
# [4 rows x 30 columns]

# %%
#add all amenities of those listings to lists
lst_1=amenities_df.transpose()[1330].unique().tolist()
lst_2=amenities_df.transpose()[1421].unique().tolist()
lst_3=amenities_df.transpose()[2746].unique().tolist()
lst_4=amenities_df.transpose()[2951].unique().tolist()
lst_1.extend(lst_2)
lst_1.extend(lst_3)
lst_1.extend(lst_4)

#convert amenities_list to no duplicate
amenities_list=set(lst_1)

# %%
amenities_df[x]= np.where(amenities_df[binary_cols]=='t', 1, 0) for x in amenities_list
# Out:
# {'24Hour Checkin',
#  'Air Conditioning',
#  'Breakfast',
#  'BuzzerWireless Intercom',
#  'Cable TV',
#  'Carbon Monoxide Detector',
#  'Dogs',
#  'Doorman',
#  'Dryer',
#  'Elevator in Building',
#  'Essentials',
#  'FamilyKid Friendly',
#  'Fire Extinguisher',
#  'First Aid Kit',
#  'Free Parking on Premises',
#  'Gym',
#  'Hair Dryer',
#  'Hangers',
#  'Heating',
#  'Hot Tub',
#  'Indoor Fireplace',
#  'Internet',
#  'Iron',
#  'Kitchen',
#  'Laptop Friendly Workspace',
#  'Pets Allowed',
#  'Pets live on this property',
#  'Pool',
#  'Safety Card',
#  'Shampoo',
#  'Smoke Detector',
#  'Suitable for Events',
#  'TV',
#  'Washer',
#  'Wheelchair Accessible',
#  'Wireless Internet'}

# %%
#get dummies for amenities_df
amenities_df=pd.get_dummies(data=amenities_df,drop_first=True)

# %% [markdown]
# Columns containing unstructured data like sentences will also not feature in the predictive model. Even though they may contain some important information, it would require to parse through those columns for commonly occurring words, so will require further feature engineering.

# %%
import nltk
from nltk.corpus import stopwords
stop = stopwords.words('english')
#add numbers to corpus
nums=[str(x) for x in range(1000)]
stop.extend(['seattle',"i've","i'm"])
stop.extend(nums)

# %%
lst1=collections.Counter(" ".join(listings_test["description"].dropna()).split()).most_common(1000)
[x for x in lst1 if x[0].lower() not in stop]
# Out:
# [('room', 3855),
#  ('kitchen', 2715),
#  ('home', 2660),
#  ('bedroom', 2653),
#  ('bed', 2516),
#  ('downtown', 2500),
#  ('apartment', 2350),
#  ('house', 2170),
#  ('space', 2069),
#  ('access', 2014),
#  ('neighborhood', 1944),
#  ('private', 1927),
#  ('bathroom', 1914),
#  ('living', 1865),
#  ('restaurants', 1843),
#  ('one', 1824),
#  ('bus', 1699),
#  ('full', 1680),
#  ('located', 1600),
#  ('floor', 1549),
#  ('walk', 1528),
#  ('away', 1525),
#  ('two', 1483),
#  ('available', 1394),
#  ('blocks', 1324),
#  ('area', 1318),
#  ('Hill', 1313),
#  ('great', 1279),
#  ('parking', 1245),
#  ('queen', 1206),
#  ('large', 1167),
#  ('quiet', 1163),
#  ('street', 1128),
#  ('minutes', 1064),
#  ('coffee', 1034),
#  ('also', 1008),
#  ('stay', 1005),
#  ('Capitol', 1003),
#  ('guests', 996),
#  ('city', 969),
#  ('comfortable', 965),
#  ('distance', 955),
#  ('walking', 947),
#  ('new', 934),
#  ('bath', 923),
#  ('Lake', 914),
#  ('unit', 865),
#  ('close', 865),
#  ('location', 859),
#  ('TV', 851),
#  ('use', 826),
#  ('shops', 824),
#  ('views', 803),
#  ('light', 795),
#  ('size', 790),
#  ('well', 789),
#  ('building', 785),
#  ('deck', 760),
#  ('beautiful', 756),
#  ('heart', 756),
#  ('need', 753),
#  ('within', 748),
#  ('place', 747),
#  ('bars', 735),
#  ('view', 724),
#  ('studio', 713),
#  ('bedrooms', 707),
#  ('dining', 701),
#  ('block', 700),
#  ('easy', 687),
#  ('Queen', 686),
#  ('cozy', 681),
#  ('Seattles', 680),
#  ('modern', 672),
#  ('enjoy', 672),
#  ('people', 670),
#  ('small', 670),
#  ('free', 656),
#  ('Park', 646),
#  ('Ballard', 631),
#  ('shared', 617),
#  ('right', 606),
#  ('everything', 603),
#  ('spacious', 589),
#  ('Washington', 589),
#  ('like', 587),
#  ('Place', 586),
#  ('Downtown', 584),
#  ('entrance', 579),
#  ('main', 578),
#  ('guest', 576),
#  ('Market', 567),
#  ('minute', 566),
#  ('clean', 565),
#  ('best', 561),
#  ('floors', 555),
#  ('Center', 554),
#  ('perfect', 541),
#  ('open', 533),
#  ('back', 533),
#  ('front', 530),
#  ('patio', 522),
#  ('Pike', 522),
#  ('fully', 518),
#  ('University', 517),
#  ('door', 516),
#  ('Space', 516),
#  ('garden', 513),
#  ('around', 505),
#  ('closet', 495),
#  ('shower', 487),
#  ('basement', 486),
#  ('laundry', 485),
#  ('many', 478),
#  ('dryer', 476),
#  ('get', 475),
#  ('Enjoy', 474),
#  ('Fremont', 471),
#  ('yard', 470),
#  ('furnished', 462),
#  ('offer', 459),
#  ('top', 452),
#  ('Guests', 451),
#  ('time', 449),
#  ('min', 448),
#  ('windows', 446),
#  ('includes', 441),
#  ('love', 435),
#  ('Private', 434),
#  ('Needle', 432),
#  ('couch', 429),
#  ('lines', 428),
#  ('make', 428),
#  ('live', 427),
#  ('shopping', 424),
#  ('mattress', 417),
#  ('lots', 414),
#  ('family', 413),
#  ('equipped', 410),
#  ('amenities', 410),
#  ('level', 407),
#  ('separate', 402),
#  ('entire', 402),
#  ('sofa', 401),
#  ('tub', 398),
#  ('Located', 396),
#  ('condo', 395),
#  ('beds', 392),
#  ('day', 389),
#  ('miles', 385),
#  ('Union', 384),
#  ('Anne', 383),
#  ('including', 383),
#  ('features', 382),
#  ('backyard', 381),
#  ('Please', 380),
#  ('take', 377),
#  ('feel', 376),
#  ('plenty', 367),
#  ('car', 367),
#  ('near', 364),
#  ('upstairs', 364),
#  ('Great', 363),
#  ('short', 357),
#  ('sized', 357),
#  ('suite', 355),
#  ('parks', 355),
#  ('work', 353),
#  ('Walk', 353),
#  ('privacy', 352),
#  ('park', 352),
#  ('water', 350),
#  ('local', 349),
#  ('UW', 348),
#  ('table', 347),
#  ('friendly', 343),
#  ('amazing', 342),
#  ('Easy', 340),
#  ('town', 337),
#  ('provided', 333),
#  ('Full', 333),
#  ('master', 332),
#  ('may', 332),
#  ('rooms', 330),
#  ('washer', 329),
#  ('cable', 327),
#  ('welcome', 326),
#  ('us', 325),
#  ('One', 322),
#  ('grocery', 320),
#  ('second', 319),
#  ('want', 319),
#  ('microwave', 317),
#  ('neighborhoods', 314),
#  ('night', 309),
#  ('gas', 308),
#  ('three', 307),
#  ('see', 307),
#  ('outdoor', 306),
#  ('ride', 305),
#  ('help', 305),
#  ('nearby', 304),
#  ('provide', 302),
#  ('center', 300),
#  ('offers', 300),
#  ('sleep', 300),
#  ('happy', 299),
#  ('District', 296),
#  ('please', 296),
#  ('next', 295),
#  ('internet', 294),
#  ('high', 293),
#  ('nice', 292),
#  ('etc', 290),
#  ('West', 288),
#  ('Free', 287),
#  ('much', 286),
#  ('towels', 286),
#  ('little', 280),
#  ('lovely', 280),
#  ('appliances', 279),
#  ('Im', 278),
#  ('questions', 277),
#  ('air', 274),
#  ('first', 274),
#  ('airport', 274),
#  ('Green', 272),
#  ('would', 272),
#  ('rail', 272),
#  ('WiFi', 271),
#  ('wifi', 271),
#  ('mile', 270),
#  ('go', 269),
#  ('bathrooms', 268),
#  ('steps', 267),
#  ('find', 266),
#  ('share', 266),
#  ('Close', 265),
#  ('stop', 264),
#  ('areas', 263),
#  ('twin', 262),
#  ('Kitchen', 261),
#  ('remodeled', 260),
#  ('fireplace', 260),
#  ('drive', 258),
#  ('across', 258),
#  ('charming', 257),
#  ('cafes', 254),
#  ('Sound', 253),
#  ('public', 252),
#  ('City', 249),
#  ('property', 249),
#  ('built', 248),
#  ('youre', 246),
#  ('bright', 245),
#  ('line', 244),
#  ('hot', 242),
#  ('stores', 242),
#  ('rooftop', 241),
#  ('outside', 241),
#  ('comfortably', 241),
#  ('lower', 241),
#  ('entry', 240),
#  ('lake', 239),
#  ('townhouse', 238),
#  ('stocked', 237),
#  ('natural', 237),
#  ('foot', 236),
#  ('brand', 236),
#  ('downstairs', 236),
#  ('fun', 235),
#  ('food', 234),
#  ('listing', 234),
#  ('old', 233),
#  ('Belltown', 233),
#  ('via', 232),
#  ('youll', 231),
#  ('convenient', 231),
#  ('nightlife', 231),
#  ('renovated', 231),
#  ('linens', 230),
#  ('check', 229),
#  ('store', 229),
#  ('major', 229),
#  ('Puget', 228),
#  ('residential', 228),
#  ('good', 228),
#  ('big', 228),
#  ('rental', 227),
#  ('style', 227),
#  ('spot', 226),
#  ('Bus', 226),
#  ('desk', 224),
#  ('w', 224),
#  ('king', 224),
#  ('Youll', 223),
#  ('Walking', 222),
#  ('Large', 221),
#  ('know', 219),
#  ('balcony', 218),
#  ('phone', 216),
#  ('corner', 215),
#  ('sq', 214),
#  ('fridge', 213),
#  ('loft', 212),
#  ('hill', 211),
#  ('hardwood', 211),
#  ('extra', 211),
#  ('sleeps', 210),
#  ('transportation', 210),
#  ('unique', 210),
#  ('side', 209),
#  ('always', 209),
#  ('art', 208),
#  ('Ave', 208),
#  ('throughout', 207),
#  ('screen', 207),
#  ('cottage', 206),
#  ('ft', 206),
#  ('urban', 205),
#  ('Netflix', 205),
#  ('needed', 204),
#  ('comfy', 204),
#  ('breakfast', 204),
#  ('staying', 204),
#  ('beach', 203),
#  ('flat', 202),
#  ('working', 202),
#  ('give', 201),
#  ('stove', 201),
#  ('Wallingford', 201),
#  ('market', 199),
#  ('looking', 199),
#  ('Beautiful', 198),
#  ('ceilings', 198),
#  ('Two', 198),
#  ('included', 197),
#  ('additional', 197),
#  ('vacation', 196),
#  ('washerdryer', 196),
#  ('key', 196),
#  ('garage', 194),
#  ('newly', 194),
#  ('Room', 194),
#  ('bike', 194),
#  ('cooking', 191),
#  ('relax', 191),
#  ('vibrant', 190),
#  ('Bedroom', 188),
#  ('waterfront', 188),
#  ('experience', 187),
#  ('wonderful', 186),
#  ('Quiet', 186),
#  ('every', 185),
#  ('dishwasher', 185),
#  ('fresh', 184),
#  ('anything', 184),
#  ('couple', 184),
#  ('single', 183),
#  ('set', 183),
#  ('feet', 182),
#  ('common', 182),
#  ('attractions', 181),
#  ('include', 180),
#  ('business', 180),
#  ('four', 179),
#  ('sleeping', 179),
#  ('futon', 179),
#  ('lot', 179),
#  ('person', 179),
#  ('central', 177),
#  ('sleeper', 176),
#  ('historic', 175),
#  ('part', 174),
#  ('maker', 174),
#  ('end', 173),
#  ('keep', 172),
#  ('furniture', 172),
#  ('plus', 172),
#  ('double', 171),
#  ('yet', 171),
#  ('tea', 171),
#  ('refrigerator', 171),
#  ('Greenlake', 171),
#  ('BBQ', 170),
#  ('meet', 170),
#  ('along', 170),
#  ('Olympic', 169),
#  ('accommodate', 169),
#  ('Amazon', 169),
#  ('long', 169),
#  ('South', 169),
#  ('New', 168),
#  ('come', 168),
#  ('transit', 167),
#  ('House', 167),
#  ('wood', 167),
#  ('cook', 167),
#  ('north', 167),
#  ('oven', 166),
#  ('square', 166),
#  ('Also', 166),
#  ('less', 166),
#  ('foam', 164),
#  ('Fully', 164),
#  ('2nd', 163),
#  ('visit', 163),
#  ('Beach', 163),
#  ('Light', 163),
#  ('safe', 162),
#  ('let', 162),
#  ('whole', 162),
#  ('station', 162),
#  ('district', 161),
#  ('morning', 161),
#  ('I5', 161),
#  ('cool', 161),
#  ('Welcome', 160),
#  ('grill', 160),
#  ('centrally', 159),
#  ('music', 159),
#  ('Alki', 159),
#  ('plan', 158),
#  ('huge', 158),
#  ('apt', 158),
#  ('Columbia', 158),
#  ('Convention', 156),
#  ('things', 155),
#  ('complete', 153),
#  ('Street', 153),
#  ('porch', 153),
#  ('several', 153),
#  ('dont', 153),
#  ('Central', 153),
#  ('doors', 152),
#  ('office', 152),
#  ('buses', 152),
#  ('completely', 151),
#  ('fantastic', 151),
#  ('quick', 150),
#  ('craftsman', 150),
#  ('stairs', 150),
#  ('designed', 150),
#  ('HIDDEN', 150),
#  ('storage', 149),
#  ('Pikes', 149),
#  ('leave', 149),
#  ('warm', 148),
#  ('ask', 148),
#  ('stops', 147),
#  ('Parking', 147),
#  ('explore', 147),
#  ('North', 147),
#  ('Wifi', 147),
#  ('upon', 146),
#  ('updated', 145),
#  ('Spacious', 144),
#  ('even', 143),
#  ('super', 143),
#  ('summer', 142),
#  ('host', 142),
#  ('comfort', 141),
#  ('bar', 141),
#  ('U', 141),
#  ('Broadway', 141),
#  ('Perfect', 140),
#  ('Access', 140),
#  ('kitchenette', 140),
#  ('popular', 139),
#  ('vintage', 139),
#  ('Bay', 138),
#  ('middle', 138),
#  ('places', 137),
#  ('range', 137),
#  ('spaces', 136),
#  ('email', 136),
#  ('sheets', 136),
#  ('conveniently', 135),
#  ('memory', 134),
#  ('wireless', 134),
#  ('community', 134),
#  ('trail', 134),
#  ('request', 133),
#  ('Bathroom', 133),
#  ('rest', 132),
#  ('Come', 132),
#  ('sink', 132),
#  ('seating', 132),
#  ('3rd', 132),
#  ('relaxing', 132),
#  ('hotel', 131),
#  ('window', 131),
#  ('upper', 131),
#  ('rent', 131),
#  ('directly', 131),
#  ('chairs', 130),
#  ('easily', 130),
#  ('Hospital', 130),
#  ('book', 129),
#  ('way', 129),
#  ('text', 128),
#  ('play', 127),
#  ('world', 127),
#  ('luxury', 127),
#  ('south', 127),
#  ('Theres', 127),
#  ('ceiling', 126),
#  ('makes', 126),
#  ('original', 126),
#  ('Living', 126),
#  ('third', 126),
#  ('filled', 125),
#  ('dishes', 125),
#  ('chair', 125),
#  ('toaster', 125),
#  ('score', 125),
#  ('ideal', 123),
#  ('Mountains', 123),
#  ('half', 122),
#  ('routes', 122),
#  ('accessible', 122),
#  ('needs', 122),
#  ('traveling', 122),
#  ('walkable', 121),
#  ('Mt', 121),
#  ('fire', 121),
#  ('enough', 120),
#  ('charm', 118),
#  ('overlooking', 117),
#  ('another', 117),
#  ('Internet', 117),
#  ('Craftsman', 117),
#  ('pool', 117),
#  ('decorated', 117),
#  ('sunny', 117),
#  ('story', 117),
#  ('player', 116),
#  ('Cozy', 116),
#  ('glass', 116),
#  ('furnishings', 116),
#  ('Guest', 116),
#  ('gym', 116),
#  ('Neighborhood', 116),
#  ('First', 116),
#  ('kids', 115),
#  ('facing', 115),
#  ('could', 115),
#  ('Modern', 115),
#  ('call', 115),
#  ('comes', 115),
#  ('used', 114),
#  ('sitting', 114),
#  ('Washer', 114),
#  ('gorgeous', 114),
#  ('days', 114),
#  ('Coffee', 113),
#  ('bunk', 113),
#  ('trees', 113),
#  ('recently', 113),
#  ('movie', 112),
#  ('Lots', 112),
#  ('entertainment', 112),
#  ('Greenwood', 112),
#  ('Apartment', 111),
#  ('tv', 111),
#  ('Laundry', 111),
#  ('Madison', 111),
#  ('travel', 110),
#  ('favorite', 110),
#  ('system', 109),
#  ('classic', 109),
#  ('Rail', 109),
#  ('Village', 109),
#  ('stainless', 108),
#  ('dog', 108),
#  ('famous', 108),
#  ('Shared', 108),
#  ('still', 108),
#  ('options', 108),
#  ('run', 108),
#  ('Airbnb', 107),
#  ('surrounded', 107),
#  ('tons', 107),
#  ('ground', 107),
#  ('Cable', 107),
#  ('Rainier', 107),
#  ('mountains', 106),
#  ('heated', 105),
#  ('travelers', 105),
#  ('years', 105),
#  ('sure', 105),
#  ('watch', 104),
#  ('Phinney', 104),
#  ('Ridge', 104),
#  ('DVD', 103),
#  ('exploring', 103),
#  ('booking', 103),
#  ('nights', 103),
#  ('answer', 102),
#  ('daylight', 102),
#  ('units', 102),
#  ('really', 102),
#  ('counter', 102),
#  ('year', 102),
#  ('Bed', 102),
#  ('anywhere', 101),
#  ('granite', 101),
#  ('something', 101),
#  ('Steps', 101),
#  ('dresser', 100),
#  ('might', 100),
#  ('Sleeps', 100),
#  ('board', 99),
#  ('Master', 99),
#  ('friends', 99),
#  ('fee', 99),
#  ('townhome', 99),
#  ('quite', 99),
#  ('Zoo', 99),
#  ('Starbucks', 99),
#  ('High', 98),
#  ('hip', 98),
#  ('keys', 98),
#  ('west', 97),
#  ('stays', 97),
#  ('trails', 97),
#  ('life', 97),
#  ('pillows', 96),
#  ('homes', 96),
#  ('walkin', 96),
#  ('wall', 96),
#  ('convenience', 96),
#  ('basic', 95),
#  ('situated', 95),
#  ('baths', 95),
#  ('mins', 95),
#  ('French', 95),
#  ('Ill', 95),
#  ('roof', 95),
#  ('Location', 94),
#  ('contact', 94),
#  ('neighbors', 94),
#  ('usually', 94),
#  ('courtyard', 94),
#  ('activities', 94),
#  ('note', 94),
#  ('peaceful', 94),
#  ('Eastlake', 94),
#  ('pretty', 93),
#  ('meal', 93),
#  ('busy', 93),
#  ('eat', 93),
#  ('arrival', 93),
#  ('hour', 93),
#  ('Well', 92),
#  ('brick', 92),
#  ('speed', 92),
#  ('inside', 92),
#  ('able', 92),
#  ('takes', 92),
#  ('wine', 92),
#  ('covered', 91),
#  ('Avenue', 91),
#  ('library', 91),
#  ('trip', 91),
#  ('retreat', 91),
#  ('fenced', 91),
#  ('Feel', 91),
#  ('possible', 91),
#  ('Comfortable', 91),
#  ('games', 91),
#  ('nook', 90),
#  ('green', 90),
#  ('secure', 90),
#  ('ample', 90),
#  ('queensized', 90),
#  ('addition', 90),
#  ('scene', 90),
#  ('utensils', 90),
#  ('visiting', 90),
#  ('gourmet', 89),
#  ('bungalow', 89),
#  ('Clean', 89),
#  ('Home', 89),
#  ('code', 89),
#  ('families', 88),
#  ('making', 88),
#  ('Burke', 88),
#  ('smart', 87),
#  ('five', 87),
#  ('restaurant', 87),
#  ('left', 87),
#  ('sharing', 87),
#  ('Air', 87),
#  ('going', 87),
#  ('show', 87),
#  ('Woodland', 87),
#  ('Beacon', 87),
#  ('simple', 86),
#  ('steel', 86),
#  ('sun', 86),
#  ('bit', 86),
#  ('service', 86),
#  ('interior', 86),
#  ('attached', 86),
#  ('hair', 86),
#  ('cute', 85),
#  ('details', 84),
#  ('Pacific', 84),
#  ('stadiums', 84),
#  ('quality', 84),
#  ('children', 84),
#  ('shop', 84),
#  ('made', 84),
#  ('electric', 84),
#  ('site', 84),
#  ('spots', 84),
#  ('adjacent', 83),
#  ('WIFI', 83),
#  ('International', 83),
#  ('airy', 83),
#  ('facilities', 83),
#  ('week', 83),
#  ('Madrona', 83),
#  ('PikePine', 83),
#  ('heat', 82),
#  ('lounge', 82),
#  ('recommendations', 82),
#  ('needle', 82),
#  ('Capital', 82),
#  ('base', 82),
#  ('duplex', 81),
#  ('bedding', 81),
#  ('Score', 81),
#  ('hang', 81),
#  ('wont', 81),
#  ('east', 81),
#  ('coming', 81),
#  ('Key', 80),
#  ('interesting', 80),
#  ('Plenty', 80),
#  ('convention', 80),
#  ('enter', 80),
#  ('Everything', 80),
#  ('Brand', 80),
#  ('Childrens', 79),
#  ('meals', 79),
#  ('personal', 79),
#  ('fan', 79),
#  ('times', 79),
#  ('Studio', 79),
#  ('look', 79),
#  ('fit', 79),
#  ('books', 79),
#  ('Square', 79),
#  ('luxurious', 78),
#  ('shampoo', 78),
#  ('adults', 78),
#  ('Pioneer', 78),
#  ('pullout', 78),
#  ('Trail', 78),
#  ('tile', 77),
#  ('reading', 77),
#  ('smaller', 77),
#  ('Uber', 77),
#  ('driveway', 77),
#  ('hours', 77),
#  ('opens', 76),
#  ('Experience', 76),
#  ('read', 76),
#  ('fabulous', 76),
#  ('sweet', 76),
#  ('information', 76),
#  ('tree', 76),
#  ('Right', 76),
#  ('pit', 76),
#  ('URL', 76),
#  ('sits', 75),
#  ('King', 75),
#  ('mind', 75),
#  ('sound', 75),
#  ('Charming', 75),
#  ('diverse', 75),
#  ('either', 75),
#  ('Northgate', 75),
#  ('Magnolia', 74),
#  ('comforts', 74),
#  ('decor', 74),
#  ('without', 74),
#  ('television', 74),
#  ('fits', 74),
#  ('eclectic', 73),
#  ('desirable', 73),
#  ('HBO', 73),
#  ('Link', 73),
#  ('dinner', 73),
#  ('excellent', 73),
#  ('meeting', 73),
#  ('Note', 73),
#  ('interact', 73),
#  ('multiple', 73),
#  ('Relax', 72),
#  ('surrounding', 72),
#  ('quaint', 72),
#  ('pull', 72),
#  ('eating', 72),
#  ('Waterfront', 72),
#  ('Dining', 72),
#  ('mini', 72),
#  ('finishes', 72),
#  ('start', 72),
#  ('Safeway', 72),
#  ('Museum', 71),
#  ('houses', 71),
#  ('Newly', 71),
#  ('Gardens', 71),
#  ('Short', 71),
#  ('items', 71),
#  ('flooring', 71),
#  ('leather', 71),
#  ('prefer', 71),
#  ('ready', 71),
#  ('beautifully', 71),
#  ('SeaTac', 71),
#  ('design', 70),
#  ('Take', 70),
#  ('trendy', 70),
#  ('Centrally', 70),
#  ('theres', 70),
#  ('real', 70),
#  ('noise', 70),
#  ('Check', 70),
#  ('per', 70),
#  ('direct', 70),
#  ('Lower', 69),
#  ('yoga', 69),
#  ('game', 69),
#  ('Small', 69),
#  ('Near', 69),
#  ('provides', 69),
#  ('apartments', 69),
#  ('early', 68),
#  ('bathtub', 68),
#  ('group', 68),
#  ('midcentury', 68),
#  ('goes', 68),
#  ('except', 68),
#  ('often', 68),
#  ('Gilman', 68),
#  ('venues', 68),
#  ('tech', 68),
#  ('pets', 67),
#  ('Hardwood', 67),
#  ('groceries', 67),
#  ('Within', 67),
#  ('getaway', 67),
#  ('minimum', 67),
#  ('lock', 67),
#  ('Rooftop', 67)]

# %%
listings_test['description']
# Out:
# 0       Make your self at home in this charming one-be...
# 1       Chemically sensitive? We've removed the irrita...
# 2       New modern house built in 2013.  Spectacular s...
# 3       A charming apartment that sits atop Queen Anne...
# 4       Cozy family craftman house in beautiful neighb...
# 5       We're renting out a small private unit of one ...
# 6       Enjoy a quiet stay in our comfortable 1915 Cra...
# 7       Our tiny cabin is private , very quiet and com...
# 8       Nestled in the heart of the city, this space i...
# 9       Beautiful apartment in an extremely safe, quie...
# 10      Queen Anne Hill is a charming neighborhood wit...
# 11      Beautifully furnished, cozy 1 bedroom mid cent...
# 12      Spacious apt in popular Seattle neighborhood. ...
# 13      Enjoy our amazing, updated & modern design cot...
# 14      Stunning Designsponge featured 6 bed, 3.75 bat...
# 15      This home is full of light, art and comfort. 5...
# 16      Master bedroom suite with 1/4 bath & kitchenet...
# 17      Beautiful private entrance garden suite overlo...
# 18      The second room in our spacious 2BR / 2 Bath a...
# 19      This  home built in 1909.  It has 5 bedrooms a...
# 20      This clean and comfortable one bedroom sits ri...
# 21      Relax in your own private finished basement sp...
# 22      Welcome to Seattle! Enjoy your stay in a  turn...
# 23      Greetings!  Our home is a beautiful, 1920's 4 ...
# 24      Enjoy Seattle from the ideally located Queen A...
# 25      Our home is very light and full of character a...
# 26      Our cozy little bungalow is the perfect place ...
# 27      Micro camper with queen size bed and seating f...
# 28      This three bedroom flat is your gorgeous retre...
# 29      Designer home situated on Queen Anne Hill over...
#                               ...
# 3788    Our apartment is bright and airy and a modern ...
# 3789    The extremely comfortable sleep number Califor...
# 3790    Private 2 bedroom retreat in the heart of Frem...
# 3791    This is a private suite with bedroom and bathr...
# 3792    Vacationing in Seattle? Traveling for business...
# 3793    Come stay at this 2014 Northwest Green Home To...
# 3794    An one-bedroom apartment in the top level of m...
# 3795    Our cool loft apartment offers a convenient lo...
# 3796    Enjoy the excitement of Seattle and city life ...
# 3797    A clean and simple mother-in-law across the st...
# 3798    Spacious 1 bedroom: private 3/4 bathroom, Quee...
# 3799    The townhouse is conveniently blocks away from...
# 3800           Seattle's most elegant and romantic lit...
# 3801    This lovely apartment is located on the lower ...
# 3802    Our rare for its location, 2 bedroom and 1 bat...
# 3803    Get anywhere in Seattle quickly from this grea...
# 3804    Comfortable and clean, this lower level suite ...
# 3805    This 2 bedroom, 1 bath garden-level apartment ...
# 3806    Charming urban home with rustic cottage feel. ...
# 3807    Adorable private studio nestled in one of Seat...
# 3808    Our charming home in fabulous Upper Fremont is...
# 3809    From the deck of this quaint little apartment ...
# 3810    Our 2BR/1 bath home in Fremont's most fun neig...
# 3811    In the true spirit of AirBNB this unit is avai...
# 3812    Of the Tree & Clouds' "Roots" apartment is 8 b...
# 3813    Our 3BR/2BA house boasts incredible views of t...
# 3814    800 square foot 1 bedroom basement apartment w...
# 3815    Very comfortable lower unit. Quiet, charming m...
# 3816    Cozy studio condo in the heart on Madison Park...
# 3817    All hardwood floors, fireplace, 65" TV with Xb...
# Name: description, Length: 3818, dtype: object

# %%
bag_of_words = vec.transform(corpus)

# %%
#make a copy to check for unstructured data

# %%
#drop unstructured data like 'summary', 'description', 'neighborhood_overview','transit',
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-cf8c94616d4f> in <module>()
# ----> 1 [len(x) for x in listings['summary'] if x!=0]
#
# <ipython-input-25-cf8c94616d4f> in <listcomp>(.0)
# ----> 1 [len(x) for x in listings['summary'] if x!=0]
#
# TypeError: object of type 'float' has no len()

# %% [markdown]
# It also could be that columns like 'host_name' or 'host_about' are not particularly predictive of the rating as they are unstructured and not indicative of any characteristics of the home.
#
# There are also redundant details like 'longitude' and 'latitude', and

# %%
drop_cols=['listing_url','scrape_id','last_scraped','thumbnail_url',
       'medium_url', 'picture_url', 'xl_picture_url', 'host_id',
       'host_url', 'host_name','host_about','host_thumbnail_url',
       'host_picture_url','country_code','latitude',
       'longitude','latitude',
       'longitude','requires_license', 'jurisdiction_names']
